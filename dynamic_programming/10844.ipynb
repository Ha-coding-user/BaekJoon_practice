# %% [markdown]
# # 10844 쉬운 계단 수 ★★

# %% [markdown]
# ### Q)
# 45656이란 수를 보자.
#
# 이 수는 인접한 모든 자리의 차이가 1이다. 이런 수를 계단 수라고 한다.
#
# N이 주어질 때, 길이가 N인 계단 수가 총 몇 개 있는지 구해보자. 0으로 시작하는 수는 계단수가 아니다.

# %% [markdown]
# ### Input)
# 첫째 줄에 N이 주어진다. N은 1보다 크거나 같고, 100보다 작거나 같은 자연수이다.

# %% [markdown]
# ### Output)
# 첫째 줄에 정답을 1,000,000,000으로 나눈 나머지를 출력한다.

# %% [markdown]
# ### Source Code)

# %%
from sys import stdin
input = stdin.readline

n = int(input())

dp = [[0 for _ in range(10)] for _ in range(n+1)]

for i in range(1, 10):
    dp[1][i] = 1

if n >= 2:
    for i in range(2, n+1):
        dp[i][0] = dp[i-1][1]
        for j in range(1, 9):
            dp[i][j] = dp[i-1][j-1] + dp[i-1][j+1]
        dp[i][9] = dp[i-1][8]

print(sum(dp[n]) % 1000000000)

# %% [markdown]
# 아직 많이 부족하다는 것을 느낀 문제...
#
# ![image.png](attachment:image.png)
#
# 위 그림은 다음 풀이를 그림으로 나타낸 것이다.
# - 0을 제외한 모든 숫자는 앞에 올 수 있다.
# - 1 ~ 8 뒤에 올 수 있는 숫자는 총 2종류이다.
# - 9 뒤에 올 수 있는 숫자는 8뿐이다.
#
# 이를 정리하면 다음과 같다.
#
# 1. 앞에 오는 숫자 = 0
# - dp[자리수][0] = dp[자리수-1][1]
#
# 2. 앞에 오는 숫자 = 1 ~ 8
# - dp[자리수][앞에 오는 숫자] = dp[자리수-1][앞에오는 숫자-1] + dp[자리수-1][앞에오는 숫자+1]
#
# 3. 앞에 오는 숫자 = 9
# - dp[자리수][8]

# %% [markdown]
# # 12865 평범한 배낭 ★★★

# %% [markdown]
# ### Q)
# 이 문제는 아주 평범한 배낭에 관한 문제이다.
#
# 한 달 후면 국가의 부름을 받게 되는 준서는 여행을 가려고 한다. 세상과의 단절을 슬퍼하며 최대한 즐기기 위한 여행이기 때문에, 가지고 다닐 배낭 또한 최대한 가치 있게 싸려고 한다.
#
# 준서가 여행에 필요하다고 생각하는 N개의 물건이 있다. 각 물건은 무게 W와 가치 V를 가지는데, 해당 물건을 배낭에 넣어서 가면 준서가 V만큼 즐길 수 있다. 아직 행군을 해본 적이 없는 준서는 최대 K만큼의 무게만을 넣을 수 있는 배낭만 들고 다닐 수 있다. 준서가 최대한 즐거운 여행을 하기 위해 배낭에 넣을 수 있는 물건들의 가치의 최댓값을 알려주자.

# %% [markdown]
# ### Input)
# 첫 줄에 물품의 수 N(1 ≤ N ≤ 100)과 준서가 버틸 수 있는 무게 K(1 ≤ K ≤ 100,000)가 주어진다. 두 번째 줄부터 N개의 줄에 거쳐 각 물건의 무게 W(1 ≤ W ≤ 100,000)와 해당 물건의 가치 V(0 ≤ V ≤ 1,000)가 주어진다.
#
# 입력으로 주어지는 모든 수는 정수이다.

# %% [markdown]
# ### Output)
# 한 줄에 배낭에 넣을 수 있는 물건들의 가치합의 최댓값을 출력한다.

# %% [markdown]
# ### Source Code)

# %%
from sys import stdin
input = stdin.readline

N, K = map(int, input().split())
things = [[0, 0]]
dp = [[0 for _ in range(K+1)] for _ in range(N+1)]

for _ in range(N):
    things.append(list(map(int, input().split())))

for i in range(1, N+1):
    weight = things[i][0]
    value = things[i][1]
    for j in range(1, K+1):
        if weight > j:
            dp[i][j] = dp[i-1][j]
        else:
            dp[i][j] = max(value + dp[i-1][j-weight], dp[i-1][j])
        
            
print(dp[N][K])

# %% [markdown]
# 동적 프로그래밍은 아직까지도 어렵다...
#
# dp라는 이차원 배열을 만들어준다.
# x축은 0 ~ k 까지의 무게, y축은 물건을 의미한다.
#
# 일단 먼저 표를 보면서 설명하겠다.
#
# ![image.png](attachment:image.png)
#
# - 현재 물건이 현재 돌고 있는 무게보다 작다면 [이전물건][같은무게]를 그대로 입력해준다.
# - 현재 물건이 현재 돌고 있는 무게보다 작지 않으면
# 1. 현재 물건을 넣고, 남은 무게를 채울 수 있는 최댓값을 이전 물건의 행에서 가져와 더한다.
# 2. 현재 물건을 넣지 않고, 이전 물건을 넣고 같은 무게인 경우의 값을 가지고 온다.
# - 1, 2 에서의 최댓값을 [현재물건][같은무게]위치에 넣어준다.
# - 즉, dp[i][j] 는 무게가 j일 때 최댓값을 의마한다.
#
# 표는 https://claude-u.tistory.com/208 에서 가지고 왔다.

# %% [markdown]
# # 1149 RGB거리

# %% [markdown]
# ### Q)
#     RGB거리에는 집이 N개 있다. 거리는 선분으로 나타낼 수 있고, 1번 집부터 N번 집이 순서대로 있다.
#
#     집은 빨강, 초록, 파랑 중 하나의 색으로 칠해야 한다. 각각의 집을 빨강, 초록, 파랑으로 칠하는 비용이 주어졌을 때, 아래 규칙을 만족하면서 모든 집을 칠하는 비용의 최솟값을 구해보자.
#
# - 1번 집의 색은 2번 집의 색과 같지 않아야 한다.
# - N번 집의 색은 N-1번 집의 색과 같지 않아야 한다.
# - i(2 ≤ i ≤ N-1)번 집의 색은 i-1번, i+1번 집의 색과 같지 않아야 한다.

# %% [markdown]
# ### Input)
#     첫째 줄에 집의 수 N(2 ≤ N ≤ 1,000)이 주어진다. 둘째 줄부터 N개의 줄에는 각 집을 빨강, 초록, 파랑으로 칠하는 비용이 1번 집부터 한 줄에 하나씩 주어진다. 집을 칠하는 비용은 1,000보다 작거나 같은 자연수이다.

# %% [markdown]
# ### Output)
#     첫째 줄에 모든 집을 칠하는 비용의 최솟값을 출력한다.

# %% [markdown]
# ### Source Code)

# %%
from sys import stdin
input = stdin.readline

N = int(input())
RGB_list = []

for i in range(N):
    RGB_list.append(list(map(int, input().split())))

for i in range(1, N):
    # i+1 번째 집을 빨간색으로 선택한 경우
    RGB_list[i][0] = min(RGB_list[i-1][1], RGB_list[i-1][2]) + RGB_list[i][0]

    # i+1 번째 집을 녹색으로 선택한 경우
    RGB_list[i][1] = min(RGB_list[i-1][0], RGB_list[i-1][2]) + RGB_list[i][1]

    # i+2 번째 집을 파란색으로 선택한 경우
    RGB_list[i][2] = min(RGB_list[i-1][0], RGB_list[i-1][1]) + RGB_list[i][2]

print(min(RGB_list[N-1]))

# %% [markdown]
# 이전의 값들을 더해서 해당 리스트에 그대로 넣어주면 된다.
# 이게 무슨 말이냐면
# - 첫 번째 집은 일단 pass하고 넘어간다.
# - 두 번째 집을 기준으로 선택할 수 있는 경우의 수는 3가지이다. (빨간색, 초록색, 파란색 각각)
# - 각 경우에 대해 현재 선택한 집과 이전에 선택한 집의 색이 달라야하는데 현재의 3가지 경우에 대해 이전의 선택할 수 있는 집들 중 비용의 min 값을 더해 현재 리스트에 넣는다. -> 알아서 이전의 집들에 대해 더해지게 됨
#
# 다음은 예제 입력 1에 대한 for문을 나타낸 것이다.
#
# ![image.png](attachment:image.png)

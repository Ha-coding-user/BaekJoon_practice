# %% [markdown]
# # 9461 파도반 수열

# %% [markdown]
# ### Q)
#     오른쪽 그림과 같이 삼각형이 나선 모양으로 놓여져 있다. 첫 삼각형은 정삼각형으로 변의 길이는 1이다. 그 다음에는 다음과 같은 과정으로 정삼각형을 계속 추가한다. 나선에서 가장 긴 변의 길이를 k라 했을 때, 그 변에 길이가 k인 정삼각형을 추가한다.
#
# ![image.png](attachment:image.png)
#
# 파도반 수열 P(N)은 나선에 있는 정삼각형의 변의 길이이다. P(1)부터 P(10)까지 첫 10개 숫자는 1, 1, 1, 2, 2, 3, 4, 5, 7, 9이다.
#
# N이 주어졌을 때, P(N)을 구하는 프로그램을 작성하시오.

# %% [markdown]
# ### Input)
#     첫째 줄에 테스트 케이스의 개수 T가 주어진다. 각 테스트 케이스는 한 줄로 이루어져 있고, N이 주어진다. (1 ≤ N ≤ 100)

# %% [markdown]
# ### Output)
#     각 테스트 케이스마다 P(N)을 출력한다.

# %%
from sys import stdin
input= stdin.readline

save_list = [0] * 101
save_list[1] = 1
save_list[2] = 1
save_list[3] = 1
save_list[4] = save_list[1] + save_list[3]
save_list[5] = save_list[4]
save_list[6] = save_list[3] + save_list[5]
save_list[7] = save_list[2] + save_list[6]
save_list[8] = save_list[1] + save_list[7]

test_case = int(input())

for i in range(test_case):
    N = int(input())

    if save_list[N] == 0:
        for i in range(9, N+1):
            save_list[i] = save_list[i-1] + save_list[i-5]

    print(save_list[N])

# %% [markdown]
# 그림을 그려 하나하나 확인해보면 과정을 확인할 수 있다.
# 위 코드는 생겨난 삼각형을 기준으로 다음 상각형을 생각한 경우이다.
#
# 하지만 다음과 같은 경우로 생각할 수 있다.
#
# ![image.png](attachment:image.png)

# %%
P = [0 for _ in range(101)]
P[1] = 1
P[2] = 1
P[3] = 1

test_case = int(input())
for i in range(test_case):
    N = int(input())

    if p[N] == 0:
        for i in range(4, N+1):
            P[i] = P[i-2] + P[i-3]

    print(P[N])

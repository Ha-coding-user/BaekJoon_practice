# %% [markdown]
# # 1697 숨바꼭질

# %% [markdown]
# ### Q)
# 수빈이는 동생과 숨바꼭질을 하고 있다. 수빈이는 현재 점 N(0 ≤ N ≤ 100,000)에 있고, 동생은 점 K(0 ≤ K ≤ 100,000)에 있다. 수빈이는 걷거나 순간이동을 할 수 있다. 만약, 수빈이의 위치가 X일 때 걷는다면 1초 후에 X-1 또는 X+1로 이동하게 된다. 순간이동을 하는 경우에는 1초 후에 2*X의 위치로 이동하게 된다.
#
# 수빈이와 동생의 위치가 주어졌을 때, 수빈이가 동생을 찾을 수 있는 가장 빠른 시간이 몇 초 후인지 구하는 프로그램을 작성하시오.

# %% [markdown]
# ### Input)
# 첫 번째 줄에 수빈이가 있는 위치 N과 동생이 있는 위치 K가 주어진다. N과 K는 정수이다.

# %% [markdown]
# ### Output)
# 수빈이가 동생을 찾는 가장 빠른 시간을 출력한다.

# %% [markdown]
# ### Source Code)

# %%
from sys import stdin
input = stdin.readline

N, K = map(int, input().split())
dist = [0] * 100001

def BFS(N, K):
    queue = []
    queue.append(N)
    while queue:
        x = queue.pop(0)
        if x == K:
            print(dist[x])
            break
        
        for next in (x-1, x+1, 2*x):
            if 0 <= next <= 100000 and dist[next] == 0:
                dist[next] = dist[x] + 1
                queue.append(next)

BFS(N, K)

# %% [markdown]
# 먼저 그림을 소개하겠다.
#
# ![image.png](attachment:image.png)
#
# 시작 root(5)에서 다음으로 갈 수 있는 번호는 4, 6, 10 3가지 노드이다.
# 위 코드에서 생성한 dist라는 리스트에서 dist[4], dist[6], dist[10]의 값을 dist[5]+1을 해준다. => 이 dist는 이동 거리라고 생각하면 됨
#
# 이런 식으로 탐색을 하다가 원하는 목적지에 도달하면 break하고 출력을 하면 된다.
